# %% [markdown]
# <a href="https://colab.research.google.com/github/SANGRAMLEMBE/MTech/blob/main/MLA_practical/MLA_lab1_student_scores_multi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
student_scores_multi = pd.read_csv('/content/student_scores_multi - student_scores_multi.csv')

# %%
student_scores_multi.head()
# Out:
#    Hours_Studied  Attendance_Rate  Assignments_Completed  Exam_Score
# 0              7               66                      8       76.46
# 1              4               80                      5       75.50
# 2              8               68                      9       91.11
# 3              5               98                      9       89.95
# 4              7               77                      6       91.40

# %%
student_scores_multi
# Out:
#     Hours_Studied  Attendance_Rate  Assignments_Completed  Exam_Score
# 0               7               66                      8       76.46
# 1               4               80                      5       75.50
# 2               8               68                      9       91.11
# 3               5               98                      9       89.95
# 4               7               77                      6       91.40
# 5               3               63                      9       60.01
# 6               7               84                      6       93.17
# 7               8               73                      5       87.98
# 8               5               68                      8       69.81
# 9               4               85                      8       78.12
# 10              8               61                      8       91.36
# 11              8               79                      9      101.48
# 12              3               87                      5       75.98
# 13              6               66                      9       82.69
# 14              5               67                      9       93.36
# 15              2               94                      5       62.40
# 16              8               73                      5       84.51
# 17              6               76                      5       77.70
# 18              2               95                      5       60.41
# 19              5               99                      8       95.71
# 20              1               63                      7       55.02
# 21              6               61                      7       74.60
# 22              9               65                      5       84.83
# 23              1               63                      7       43.02
# 24              3               88                      7       69.05
# 25              7               77                      5       87.22
# 26              4               85                      7       75.44
# 27              9               93                      9      107.37
# 28              3               69                      6       64.01
# 29              5               95                      6       90.29

# %%
# Split the complete attributes into "Input" and "Output" attributes

x = student_scores_multi[['Hours_Studied','Attendance_Rate','Assignments_Completed']] # for multiple columns input , we have to use List
y = student_scores_multi['Exam_Score']

# %%
from sklearn.model_selection import train_test_split #splitting of data

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size = 0.2 , random_state = 101)

# %%
x_train # to view the train , test records
# Out:
#     Hours_Studied  Attendance_Rate  Assignments_Completed
# 26              4               85                      7
# 16              8               73                      5
# 25              7               77                      5
# 28              3               69                      6
# 10              8               61                      8
# 3               5               98                      9
# 1               4               80                      5
# 19              5               99                      8
# 22              9               65                      5
# 12              3               87                      5
# 5               3               63                      9
# 14              5               67                      9
# 0               7               66                      8
# 21              6               61                      7
# 4               7               77                      6
# 8               5               68                      8
# 13              6               66                      9
# 9               4               85                      8
# 15              2               94                      5
# 29              5               95                      6
# 23              1               63                      7
# 6               7               84                      6
# 17              6               76                      5
# 11              8               79                      9

# %%
x_test
# Out:
#     Hours_Studied  Attendance_Rate  Assignments_Completed
# 20              1               63                      7
# 24              3               88                      7
# 7               8               73                      5
# 18              2               95                      5
# 2               8               68                      9
# 27              9               93                      9

# %%
y_train
# Out:
# 26     75.44
# 16     84.51
# 25     87.22
# 28     64.01
# 10     91.36
# 3      89.95
# 1      75.50
# 19     95.71
# 22     84.83
# 12     75.98
# 5      60.01
# 14     93.36
# 0      76.46
# 21     74.60
# 4      91.40
# 8      69.81
# 13     82.69
# 9      78.12
# 15     62.40
# 29     90.29
# 23     43.02
# 6      93.17
# 17     77.70
# 11    101.48
# Name: Exam_Score, dtype: float64

# %%
y_test
# Out:
# 20     55.02
# 24     69.05
# 7      87.98
# 18     60.41
# 2      91.11
# 27    107.37
# Name: Exam_Score, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %% [markdown]
# lm.fit(x_train, y_train) is used to train the linear regression model initialized in the previous step.
#
#
# * lm: This is the LinearRegression model object.
# * .fit(): This is the method used to train the model.

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# prediction = lm.predict([[4,85,7]])
prediction = lm.predict(x_train)

prediction
# Out:
# array([ 77.91461739,  88.58927156,  85.45191123,  60.4984674 ,
#         87.76288977,  95.66173388,  70.58198637,  94.1179132 ,
#         89.30092353,  69.26390731,  63.31064818,  76.86249398,
#         85.23195653,  74.48650457,  87.602159  ,  75.31867329,
#         81.81913559,  80.06486517,  67.94582826,  87.39170927,
#         47.8840152 ,  91.84714866,  79.28241542, 100.82882524])

# %%
prediction = lm.predict(x_test)

prediction
# Out:
# array([ 47.8840152 ,  74.17082996,  88.58927156,  68.55225535,
#         94.15812721, 114.88187326])

# %%
y_test
# Out:
# 20     55.02
# 24     69.05
# 7      87.98
# 18     60.41
# 2      91.11
# 27    107.37
# Name: Exam_Score, dtype: float64

# %% [markdown]
# ![Screenshot 2025-08-20 105846.png](data:image/png;base64,...)

# %%
print(lm.intercept_)

#displays the y-intercept of the linear regression model (lm)
# Out:
# -10.93569486218594

# %%
print(lm.coef_)
# Out:
# [5.56306871 0.60642709 2.15024778]

# %%
yy = lm.intercept_ + lm.coef_ * x  # fromula : Y = Mx + c
round(yy,0)
# Out:
#     Hours_Studied  Attendance_Rate  Assignments_Completed
# 0            28.0             29.0                    6.0
# 1            11.0             38.0                   -0.0
# 2            34.0             30.0                    8.0
# 3            17.0             48.0                    8.0
# 4            28.0             36.0                    2.0
# 5             6.0             27.0                    8.0
# 6            28.0             40.0                    2.0
# 7            34.0             33.0                   -0.0
# 8            17.0             30.0                    6.0
# 9            11.0             41.0                    6.0
# 10           34.0             26.0                    6.0
# 11           34.0             37.0                    8.0
# 12            6.0             42.0                   -0.0
# 13           22.0             29.0                    8.0
# 14           17.0             30.0                    8.0
# 15            0.0             46.0                   -0.0
# 16           34.0             33.0                   -0.0
# 17           22.0             35.0                   -0.0
# 18            0.0             47.0                   -0.0
# 19           17.0             49.0                    6.0
# 20           -5.0             27.0                    4.0
# 21           22.0             26.0                    4.0
# 22           39.0             28.0                   -0.0
# 23           -5.0             27.0                    4.0
# 24            6.0             42.0                    4.0
# 25           28.0             36.0                   -0.0
# 26           11.0             41.0                    4.0
# 27           39.0             45.0                    8.0
# 28            6.0             31.0                    2.0
# 29           17.0             47.0                    2.0

# %%
# Get the names of the independent variables
independent_variables = x.columns

# Plot each independent variable against the actual and predicted exam scores
for col in independent_variables:
    plt.figure(figsize=(8, 6)) # Create a new figure for each plot
    plt.scatter(x_test[col], y_test, label='Actual Exam Score')
    plt.scatter(x_test[col], prediction, label='Predicted Exam Score')
    plt.xlabel(col)
    plt.ylabel('Exam Score')
    plt.title(f'Actual vs. Predicted Exam Score based on {col}')
    plt.legend()
    plt.show()

# %%
print(y_test)
print(prediction)
# Out:
# 20     55.02
# 24     69.05
# 7      87.98
# 18     60.41
# 2      91.11
# 27    107.37
# Name: Exam_Score, dtype: float64
# [ 47.8840152   74.17082996  88.58927156  68.55225535  94.15812721
#  114.88187326]

# %%
# Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae = mean_absolute_error(y_test,prediction)
mse = mean_squared_error(y_test,prediction)
r2 = r2_score(y_test,prediction)

# %%
print(mae, mse, r2)
# Out:
# 5.261390358336993 34.92200533660641 0.8978002104849254

# %%
y_test = [55,69,87]
prediction = [47 ,74 , 88]
mean_absolute_error(y_test,prediction)
# Out:
# 4.666666666666667

# %%
y_test.describe()
# Out:
# count      6.000000
# mean      78.490000
# std       20.249542
# min       55.020000
# 25%       62.570000
# 50%       78.515000
# 75%       90.327500
# max      107.370000
# Name: Exam_Score, dtype: float64
