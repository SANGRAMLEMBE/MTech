# %% [markdown]
# # M.Tech Python Programming — Colab Worksheet
# **Deep Neural Network Architectures — 21CSE558T (M.Tech) • SRM University**
# Instructor: **Prof. Ramesh Babu**
#
# This worksheet assesses Python proficiency from foundations to advanced topics. Solve directly in the code cells provided. Keep solutions clean, idiomatic, and tested.

# %%
# You may import standard libraries as needed per question.
import math, statistics, itertools, functools, collections, re, json, csv, datetime, statistics
from collections import Counter, defaultdict, deque
from pathlib import Path
from dataclasses import dataclass
from typing import *
import random, time
# For data/ML tier (later cells) you may use numpy/pandas/matplotlib/sklearn if available.
# import numpy as np; import pandas as pd; import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### Tier A Q1: String parse — order line
# **Data:** `"order#A12, qty=7, price=19.95"`
#
# **Task:** Extract id, qty(int), price(float) → dict.
#
# *Hint:* Use split/partition/regex.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q2: List dedup & sort desc
# **Data:** `[5,3,5,2,9,2,1,5]`
#
# **Task:** Remove duplicates, sort descending.
#
# *Hint:* set or dict; mind stability.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q3: Top-2 word frequency
# **Data:** `"to be or not to be that is the question"`
#
# **Task:** Return two most common words.
#
# *Hint:* collections.Counter

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q4: Matrix transpose (lists)
# **Data:** `[[1,2,3],[4,5,6]]`
#
# **Task:** Return transpose without NumPy.
#
# *Hint:* zip(*M) or loops

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q5: CSV avg score
# **Data:** `CSV rows: name,score`
#
# **Task:** Write to students.csv, read, compute average.
#
# *Hint:* csv.DictReader

# %%
# Step 1: Write a CSV file
import csv

rows = [
    {"name": "Alice", "score": 85},
    {"name": "Bob", "score": 92},
    {"name": "Charlie", "score": 78}
]

with open("students.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=["name", "score"])
    writer.writeheader()
    writer.writerows(rows)

print("✅ students.csv created!")

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q6: Sum valid ints with errors
# **Data:** `["10","x","25","-3",""]`
#
# **Task:** Sum only valid integers; ignore malformed.
#
# *Hint:* try/except

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q7: Date + n days
# **Data:** `"2024-03-28", n=45`
#
# **Task:** Print resulting date (ISO).
#
# *Hint:* datetime + timedelta

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q8: Comprehension filter map
# **Data:** `["Alice","Bob","Ana","Arjun","Ben"]`
#
# **Task:** Dict {name:len} for names starting with 'A'.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q9: Sort by multiple keys
# **Data:** `[("Ana",25),("Bob",30),("Alice",22)]`
#
# **Task:** Sort by age then name (asc).
#
# *Hint:* key=lambda t:(t[1], t[0])

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q10: Slice pattern
# **Data:** `"abcdefghij"`
#
# **Task:** Reverse every 2 chars → 'badcfehgj'.
#
# *Hint:* s[1::-1] like pattern

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q11: Min/max without builtins
# **Data:** `[12,5,7,9,2,10]`
#
# **Task:** Compute min and max in one pass.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q12: Running sum
# **Data:** `[1,2,3,4,5]`
#
# **Task:** Return list of cumulative sums.
#
# *Hint:* itertools.accumulate or loop

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q13: Anagram check
# **Data:** `"listen", "silent"`
#
# **Task:** Return True if anagrams.
#
# *Hint:* Counter or sorted

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q14: Unique preserve order
# **Data:** `[1,2,1,3,2,4,3]`
#
# **Task:** Return list with first occurrences preserved.
#
# *Hint:* seen set

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q15: Dot product
# **Data:** `a=[1,2,3], b=[4,5,6]`
#
# **Task:** Compute scalar dot product.
#
# *Hint:* sum(ax*b)

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q16: FizzBuzz
# **Data:** `n=20`
#
# **Task:** Print 1..n replacing multiples of 3/5/both.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q17: JSON flatten (1 level)
# **Data:** `{"a":1, "b":{"c":2}}`
#
# **Task:** Flatten to {'a':1,'b.c':2}.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q18: Roman to int
# **Data:** `"MCMXCIV"`
#
# **Task:** Convert Roman numeral to integer.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q19: Palindrome (ignore non-alnum)
# **Data:** `"A man, a plan, a canal: Panama"`
#
# **Task:** Return True/False.
#
# *Hint:* str.isalnum

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q20: Mode of list
# **Data:** `[1,2,2,3,3,3,2]`
#
# **Task:** Return statistical mode.
#
# *Hint:* Counter.most_common

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q21: Binary to decimal
# **Data:** `"101101"`
#
# **Task:** Convert to integer (no int(base=2)).

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q22: File read lines
# **Data:** `poem.txt with lines`
#
# **Task:** Read file, count lines, words, chars.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q23: Median of list
# **Data:** `[7,1,3,9,5]`
#
# **Task:** Compute median (no statistics.median).

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q24: Group by length
# **Data:** `["hi","hello","cat","at"]`
#
# **Task:** Map length→list of words.
#
# *Hint:* defaultdict(list)

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q25: Find primes ≤ N
# **Data:** `N=100`
#
# **Task:** Return all primes up to N.
#
# *Hint:* Sieve of Eratosthenes

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q26: Rotate list k
# **Data:** `arr=[1,2,3,4,5], k=2`
#
# **Task:** Right-rotate by k.
#
# *Hint:* slicing

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q27: Balanced brackets
# **Data:** `"{[()]}"`
#
# **Task:** True if brackets balanced.
#
# *Hint:* stack

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q28: Count vowels
# **Data:** `"OpenAI ChatGPT"`
#
# **Task:** Return dict of vowel counts.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q29: Run-length encoding
# **Data:** `"aaabbcaaa"`
#
# **Task:** Return list of (char,count).

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier A Q30: 2D search
# **Data:** `grid, target`
#
# **Task:** Find coordinates of target value.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q1: Regex log parse
# **Data:** `"[2025-08-17 05:10:03] INFO user=42 action=login time=123ms"`
#
# **Task:** Extract datetime,user,action,time(ms) to dict.
#
# *Hint:* use re groups

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q2: Running average generator
# **Data:** `stream: 10,20,30,40,50`
#
# **Task:** Generator yields running average.
#
# *Hint:* yield each step

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q3: Flatten nested (arbitrary)
# **Data:** `[1,[2,[3,4],5],6]`
#
# **Task:** Flatten list; handle any depth.
#
# *Hint:* recursion or stack

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q4: Vector2D class
# **Data:** `Vector2D(x,y)`
#
# **Task:** Implement add, sub, abs, repr, equality.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q5: Dataclass Student(order=True)
# **Data:** `Student(name,gpa,credits)`
#
# **Task:** Sort by gpa desc then name.
#
# *Hint:* dataclasses

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q6: JSON→CSV normalize
# **Data:** `[{"a":1,"b":2},{"a":3,"c":4}]`
#
# **Task:** Write CSV with stable headers a,b,c.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q7: Pytest fizzbuzz
# **Data:** `fizzbuzz(n)`
#
# **Task:** Write tests for multiple cases.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q8: Timezone convert
# **Data:** `Asia/Kolkata → UTC`
#
# **Task:** Convert times, compute durations.
#
# *Hint:* zoneinfo

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q9: LRU cache fib
# **Data:** `fib(35)`
#
# **Task:** Memoize and show speedup.
#
# *Hint:* functools.lru_cache

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q10: Timed context manager
# **Data:** `with timer():`
#
# **Task:** Print elapsed ms.
#
# *Hint:* time.perf_counter

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q11: File dedup by hash
# **Data:** `dir with files`
#
# **Task:** Find duplicates by sha256.
#
# *Hint:* hashlib, Path.rglob

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q12: CSV pivot (manual)
# **Data:** `transactions.csv`
#
# **Task:** Compute sum by (category,month).
#
# *Hint:* csv + dict

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q13: Config parser
# **Data:** `INI content`
#
# **Task:** Load sections → dict; support types.
#
# *Hint:* configparser

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q14: Iterator class
# **Data:** `Range-like iterator`
#
# **Task:** Build custom iterable with __iter__/__next__.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q15: Regex email extract
# **Data:** `text with emails`
#
# **Task:** Return unique emails sorted.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q16: UUID index file
# **Data:** `lines of text`
#
# **Task:** Map uuid→line_no for each line.
#
# *Hint:* uuid4

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q17: Argparse CLI
# **Data:** `script -i input.txt -o out.json`
#
# **Task:** Parse args & perform conversion.
#
# *Hint:* argparse

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q18: JSON schema validate (basic)
# **Data:** `simple schema`
#
# **Task:** Validate dict keys/types.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q19: CSV to dict of lists
# **Data:** `scores.csv`
#
# **Task:** Build {name:[scores...]}.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q20: ZIP files programmatically
# **Data:** `folder path`
#
# **Task:** Zip everything under folder.
#
# *Hint:* zipfile

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q21: Random sampling
# **Data:** `population range(1000)`
#
# **Task:** Sample k=20 unique items.
#
# *Hint:* random.sample

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q22: Top-k by value
# **Data:** `dict of counts`
#
# **Task:** Return top-3 items by count.
#
# *Hint:* heapq.nlargest

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q23: Regex redact
# **Data:** `text with phone numbers`
#
# **Task:** Mask digits except last 2.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q24: Sliding window max
# **Data:** `nums, k`
#
# **Task:** Compute window maxima efficiently.
#
# *Hint:* deque

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q25: CSV diff
# **Data:** `old.csv vs new.csv`
#
# **Task:** Print added/removed/changed rows.
#
# *Hint:* keys

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q26: JSON merge (deep)
# **Data:** `two nested dicts`
#
# **Task:** Deep-merge with conflict rules.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q27: Histogram bins
# **Data:** `list of floats`
#
# **Task:** Return bins and counts.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q28: INI write & read
# **Data:** `settings`
#
# **Task:** Write then read and verify.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q29: Path cleanup
# **Data:** `messy file names`
#
# **Task:** Normalize names, move to folders.
#
# *Hint:* pathlib, re

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier B Q30: Unit conversion
# **Data:** `list like '10km','500m'`
#
# **Task:** Normalize to meters (float).

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q1: Decorator: retry with backoff
# **Data:** `flaky() fails randomly`
#
# **Task:** Implement @retry(times=3, base=0.1).

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q2: Context manager: temporary dir
# **Data:** `with tempdir():`
#
# **Task:** Create/delete temp directory safely.
#
# *Hint:* tempfile, shutil

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q3: Threading: I/O URLs
# **Data:** `httpbin.org/delay/1 x10`
#
# **Task:** Fetch concurrently; compare time.
#
# *Hint:* concurrent.futures

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q4: Multiprocessing: Monte Carlo π
# **Data:** `N=5_000_000`
#
# **Task:** Estimate π using processes.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q5: Asyncio: gather coroutines
# **Data:** `5 tasks with sleep`
#
# **Task:** Ensure total time < sequential.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q6: Profiling: loop vs numpy
# **Data:** `1e7 floats`
#
# **Task:** Compare time with timeit.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q7: Typing Protocols
# **Data:** `SupportsArea`
#
# **Task:** Generic area(shape) with Protocol.
#
# *Hint:* typing.Protocol

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q8: Itertools recipes
# **Data:** `purchases (user,amount,time)`
#
# **Task:** Top-3 spenders per hour.
#
# *Hint:* groupby, Counter

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q9: SQLite mini-ETL
# **Data:** `orders.csv`
#
# **Task:** Create table, insert, sum per category.
#
# *Hint:* sqlite3

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q10: Sockets: echo server
# **Data:** `localhost port`
#
# **Task:** Implement echo server & client.
#
# *Hint:* socket

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q11: Decorator: time+log
# **Data:** `any fn`
#
# **Task:** Decorator that logs args & time.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q12: Context manager: suppress
# **Data:** `errors to log`
#
# **Task:** Suppress specific exceptions to log.
#
# *Hint:* contextlib

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q13: Thread-safe counter
# **Data:** `n threads`
#
# **Task:** Increment shared counter safely.
#
# *Hint:* Lock

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q14: Async rate limiter
# **Data:** `api calls`
#
# **Task:** Limit QPS with asyncio.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q15: Multiprocessing map
# **Data:** `cpu-bound f`
#
# **Task:** Parallel map over data.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q16: Heap-based scheduler
# **Data:** `tasks (time, fn)`
#
# **Task:** Min-heap schedule simulator.
#
# *Hint:* heapq

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q17: LRU cache (manual)
# **Data:** `capacity k`
#
# **Task:** Implement LRU with OrderedDict.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q18: Tokenizer + parser
# **Data:** `simple expr`
#
# **Task:** Eval +,-,*,/ with precedence.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q19: CSV streaming
# **Data:** `huge.csv`
#
# **Task:** Stream and compute mean of column.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q20: Regex tokenizer (words)
# **Data:** `unicode text`
#
# **Task:** Split words, lower, remove stopwords.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q21: Rate of change (diff)
# **Data:** `list of numbers`
#
# **Task:** Compute first and second differences.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q22: Partial application
# **Data:** `pow(base,exp)`
#
# **Task:** Make square(), cube() via partial.
#
# *Hint:* functools.partial

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q23: Memoized DFS
# **Data:** `graph adjacency`
#
# **Task:** Count paths s→t with memo.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q24: UUID vs ULID
# **Data:** `generate ids`
#
# **Task:** Compare lexicographic orderability.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q25: Tar/zip streaming
# **Data:** `folder`
#
# **Task:** Create .tar.gz in streaming mode.
#
# *Hint:* tarfile, gzip

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q26: Binary file IO
# **Data:** `write/read struct`
#
# **Task:** Pack/unpack records.
#
# *Hint:* struct

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q27: Custom iterator protocol
# **Data:** `prime generator`
#
# **Task:** Iterable yielding primes up to N.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q28: Topological sort
# **Data:** `DAG edges`
#
# **Task:** Return order using Kahn's algo.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q29: Diff two dicts (deep)
# **Data:** `d1 vs d2`
#
# **Task:** Return added/removed/changed paths.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier C Q30: Shortest path (Dijkstra)
# **Data:** `weighted graph`
#
# **Task:** Implement Dijkstra; return path.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q1: NumPy broadcasting (outer)
# **Data:** `A shaped (3,1), B shaped (1,4)`
#
# **Task:** Compute outer sum and outer product; report shapes.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q2: Pairwise distance matrix
# **Data:** `X shape (N,d)`
#
# **Task:** Compute Euclidean distance matrix w/o loops.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q3: Pandas groupby revenue
# **Data:** `date,region,product,qty,price`
#
# **Task:** Revenue per region×product; top-2 products/region.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q4: Pandas join + CLV
# **Data:** `customers, orders`
#
# **Task:** Left-join, fill NAs, CLV per customer.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q5: Matplotlib time series
# **Data:** `cpu usage list`
#
# **Task:** Plot with rolling mean (5); mark max/min.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q6: Logistic regression (sklearn)
# **Data:** `2D blobs`
#
# **Task:** Train/test, accuracy, decision boundary.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q7: Log-sum-exp (stable)
# **Data:** `array with large magnitudes`
#
# **Task:** Implement stable logsumexp; compare naive.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q8: Vectorization challenge
# **Data:** `10M ints`
#
# **Task:** Count divisible by 3 or 5; compare Py vs NumPy.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q9: Chunked CSV mean
# **Data:** `large CSV`
#
# **Task:** Read in chunks; stream mean equals full read.

# %%
# Write your solution here

# %% [markdown]
# ---
# ### Tier D Q10: Tiny backprop (1 neuron)
# **Data:** `x,y pairs`
#
# **Task:** Gradient descent for y=wx+b; plot loss vs epochs.

# %%
# Write your solution here
